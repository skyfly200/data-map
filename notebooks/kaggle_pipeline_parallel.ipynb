# %% [markdown]
# # Mushroom Observation Data Pipeline — Parallel (Streaming) Notebook
#
# This is the **parallel** variant of `kaggle_pipeline.ipynb`. Instead of running
# the whole fetch and then the whole enrichment back to back, the run step overlaps
# them: a producer thread fetches one location at a time and hands each finished
# location to a pool of enrichment workers, so the next location is fetched while
# the last is enriched. iNaturalist (rate-limited) and Earth Engine are different
# services, so overlapping them keeps both busy.
#
# Everything is still resumable and both stores are written incrementally, so a run
# that stops part-way keeps whole locations. The map GeoJSON grows after each
# location, and clustering + the final export run once at the end.
#
# Prefer the classic one-stage-at-a-time flow? Use `kaggle_pipeline.ipynb`.
#
# Every environmental layer is sampled from **Google Earth Engine** at the
# observation points, so the run downloads no bulk rasters.
#
# ## Setup Instructions
#
# ### Before Running:
# 1. **Enable Internet** in Kaggle notebook settings (Settings → Internet → On)
# 2. **Add Secrets** (Kaggle Add-ons → Secrets):
#    - `EARTHENGINE_PROJECT`: your Google Cloud project ID — the only credential
#      the pipeline needs. Step 2 below prints where to find it if you are unsure.
#    - Optional, fallback only: `OPENTOPOGRAPHY_API_KEY`, `CDSAPI_URL` / `CDSAPI_KEY`.
#
# ### Data Storage:
# Kaggle provides `/kaggle/working/` for output files that persist after the session.

# %% [markdown]
# ## Step 1: Install Dependencies & Clone the Repo

# %%
# !pip install -q pyinaturalist earthengine-api requests numpy scipy pandas scikit-learn python-dotenv "meteostat>=2.0"

# Fallback-only extras (bulk raster downloads, used when Earth Engine is
# unavailable or FETCH_RASTERS=1):
# !pip install -q cdsapi xarray netCDF4 rasterio rio-cogeo

# %%
# Clone the repo into the Kaggle working directory. Safe to re-run: an existing
# checkout is updated rather than re-cloned.
import os
import subprocess
import sys

WORKING_DIR = '/kaggle/working'
REPO_DIR = os.path.join(WORKING_DIR, 'data-map')

if os.path.isdir(os.path.join(REPO_DIR, 'scripts')):
    subprocess.run(['git', '-C', REPO_DIR, 'pull', '--ff-only'], check=False)
else:
    subprocess.run(
        ['git', 'clone', '--depth', '1',
         'https://github.com/skyfly200/data-map.git', REPO_DIR],
        check=True,
    )

# scripts/ holds the stage modules; the repo root holds utils/ and the data store.
for path in (os.path.join(REPO_DIR, 'scripts'), REPO_DIR):
    if path not in sys.path:
        sys.path.insert(0, path)
os.chdir(REPO_DIR)

print('Repo:', REPO_DIR)

# %% [markdown]
# ## Step 2: Configure Environment

# %%
import os
from kaggle_secrets import UserSecretsClient

# The pipeline defaults to <repo>/data for the per-species store, which is now
# the working directory, so DATA_DIR needs no override. Set it only to relocate
# the store (e.g. onto a Kaggle dataset mount).
# os.environ['DATA_DIR'] = '/kaggle/working/data'

user_secrets = UserSecretsClient()

# The only credential the Earth Engine path needs.
try:
    os.environ['EARTHENGINE_PROJECT'] = user_secrets.get_secret('EARTHENGINE_PROJECT')
    print("\u2713 Earth Engine project ID loaded")
except Exception as e:
    print(f"\u26a0 Earth Engine project not found: {e}")
    print("  Add it in Add-ons \u2192 Secrets \u2192 EARTHENGINE_PROJECT")

# Optional, fallback only: read when Earth Engine is unavailable, or when
# FETCH_RASTERS=1 asks for the source rasters on purpose.
try:
    os.environ['OPENTOPOGRAPHY_API_KEY'] = user_secrets.get_secret('OPENTOPOGRAPHY_API_KEY')
    print("\u2713 OpenTopography API key loaded (raster fallback)")
except Exception:
    print("\u2139 No OpenTopography key \u2014 not needed while Earth Engine is available")

try:
    cds_url = user_secrets.get_secret('CDSAPI_URL')
    cds_key = user_secrets.get_secret('CDSAPI_KEY')
    os.environ['CDSAPI_URL'] = cds_url
    os.environ['CDSAPI_KEY'] = cds_key
    with open(os.path.expanduser('~/.cdsapirc'), 'w') as f:
        f.write(f'url: {cds_url}\nkey: {cds_key}\n')
    print("\u2713 CDS API credentials loaded (raster fallback)")
except Exception:
    print("\u2139 No CDS credentials \u2014 not needed while Earth Engine is available")

# Which Google Cloud project will Earth Engine use? Prints where to find one if
# it is not configured yet.
import preflight
preflight.print_earthengine_project()

# %%
# Which taxa, and where. Set here so a Kaggle run needs no .env file.
#
# SPECIES is a comma-separated list of iNaturalist taxa (genus names work well).
# INAT_LOCATIONS is a semicolon-separated list of "lat,lng,radius_km" — every
# species is fetched around every location, so this is how you cover more than
# one region in a single run. (A single INAT_LOCATION / INAT_RADIUS still works
# for the one-region case.)
import os

os.environ['SPECIES'] = (
    'auricularia, tremella, xylaria, cordyceps, ganoderma, tricholoma, '
    'hydnellum, hydnum, clavariadelphus, pleurotus, hericium, morchella, '
    'amanita, boletus, sarcodon, russula, lactarius, cortinarius, clitocybe, '
    'hypholoma, hygrophorus, psilocybe, coprinus, coprinopsis, marasmius, '
    'mycena, lepiota, agaricus, flammulina, boletopsis, albatrellus, '
    'fomitopsis, trametes, trichaptum, lanmaoa, hypomyces, cantharellus, '
    'grifola, laetiporus, armillaria, rhizopogon'
)

# Multiple regions: Mt Hood, Oregon (100 km) and the Colorado Front Range (500 km).
os.environ['INAT_LOCATIONS'] = '45.108,-121.762,100; 40.0,-105.0,500'

# Alternatively, define areas by plus code. Each code's rectangular cell is
# fetched as a bounding box (not a radius). Use a shorter, zero-padded full code
# for a larger box: 84QW4600+ ~5.5 km, 84QW0000+ ~111 km, 85000000+ ~2200 km
# (drop trailing pairs only). Semicolon-separated; combined with INAT_LOCATIONS.
# os.environ['INAT_PLUS_CODES'] = '84QW0000+; 85GP2200+'

# Parallel enrichment: how many locations to enrich at once while fetching runs.
# Each worker issues its own Earth Engine requests — raise it only if EE keeps up,
# lower to 1 if you see EE quota errors. (EXPORT_EACH_AREA=0 turns off the
# grow-the-map-as-you-go GeoJSON export.)
os.environ['STREAM_ENRICH_WORKERS'] = '2'

species = [s.strip() for s in os.environ['SPECIES'].split(',') if s.strip()]
print(f"Species ({len(species)}):", ', '.join(species))
print("Locations:", os.environ['INAT_LOCATIONS'])
print("Enrichment workers:", os.environ['STREAM_ENRICH_WORKERS'])

# %% [markdown]
# ## Step 3: Authenticate Earth Engine

# %%
import ee

# Kaggle has no browser, so authenticate in notebook mode if there is no stored
# credential yet. run_all() below will also initialise EE on its own.
try:
    ee.Initialize(project=os.environ.get('EARTHENGINE_PROJECT'))
    print("\u2713 Earth Engine initialized")
except Exception as e:
    print(f"Earth Engine not initialized yet ({e}); authenticating...")
    ee.Authenticate(auth_mode='notebook')
    ee.Initialize(project=os.environ.get('EARTHENGINE_PROJECT'))
    print("\u2713 Earth Engine initialized")

# %% [markdown]
# ## Step 4: Run the Pipeline (fetch + enrich in parallel)
#
# One call runs the whole streaming pipeline: fetch and enrichment overlap, the map
# GeoJSON grows as each location finishes, and clustering + the final export run
# once at the end. It reads the same environment variables as the CLI and is fully
# resumable — re-run this cell and it continues where it left off.
#
# | Variable | Effect |
# | --- | --- |
# | `STREAM_ENRICH_WORKERS=n` | locations enriched at once (Step 2; lower to 1 on EE quota errors) |
# | `REFRESH_ALL=1` | re-fetch and re-enrich everything |
# | `USE_EARTH_ENGINE=0` | Earth Engine off (raster fallback only) |
# | `EE_REQUEST_DEADLINE_MS=120000` | per-request Earth Engine deadline (unstick a hung sample) |
# | `EXPORT_EACH_AREA=0` | stop rebuilding the GeoJSON after every location |

# %%
import importlib
import run_pipeline
import run_streaming
# Reload in case Step 1 pulled a newer checkout after these were first imported.
importlib.reload(run_pipeline)
importlib.reload(run_streaming)

print('Pipeline root:', run_pipeline.ROOT_DIR)

# Pre-flight: print which data sources are configured before any work starts.
run_pipeline.run_preflight()

# %%
# Fetch and enrich in parallel, then cluster + export once at the end.
# A producer thread fetches one location at a time (writing each species as it
# lands) and hands each finished location to STREAM_ENRICH_WORKERS enrichment
# workers, so the next location is fetched while the last is enriched. The map
# GeoJSON grows after each location; a run that stops part-way keeps whole
# locations. Re-run to resume.
run_streaming.run_streaming()

# %% [markdown]
# ## Step 5: Review Results

# %%
import pandas as pd
import species_store as store

df = store.load_all(store.ENRICHED_DIR)
if df.empty:
    raise SystemExit(f"No enriched observations in {store.ENRICHED_DIR}/ — run Step 4 first.")

print(f"{len(df)} enriched observations, {df['species'].nunique()} species\n")

# Coverage per environmental column — how much Earth Engine actually filled in.
cols = ['ndvi', 'soil_moisture', 'land_cover', 'elevation', 'slope', 'aspect',
        'solar_exposure', 'wind_exposure', 'water_retention',
        'prcp_d0', 'prcp_d6', 'tmax_d0', 'tmin_d6', 'cluster',
        'location_precision']
present = [c for c in cols if c in df.columns]
coverage = pd.DataFrame({
    'filled': [df[c].notna().sum() for c in present],
    'missing': [df[c].isna().sum() for c in present],
    'coverage': [f"{df[c].notna().mean() * 100:.1f}%" for c in present],
}, index=present)
print(coverage.to_string())

# %% [markdown]
# ## Step 6: How much of this can you trust?
#
# Coverage above says whether a value is *present*. This says whether it is
# *about the right place*.
#
# iNaturalist does not always publish where an observation actually was. A record
# is **obscured** when the observer asks for it, or automatically when the taxon is
# threatened — and obscuring is not a rounding. The published point is randomised
# inside a roughly 0.2° cell, about **20 km** across.
#
# That matters here more than it would in most analyses, because every
# environmental value this pipeline attaches is sampled **at the point**:
# elevation, slope, aspect, NDVI, soil moisture, and the seven-day weather lead-up.
# For an obscured record those readings come from wherever the randomised point
# landed — the far side of a ridge, a different watershed, a thousand metres up.
# The observation is real; the terrain attached to it describes somewhere else.
#
# The fetch records this as `location_precision`:
#
# | Value | Meaning |
# | --- | --- |
# | `precise` | accuracy of 1 km or better — good enough to read the ground |
# | `coarse` | honest but vague: no obscuring, accuracy wider than 1 km |
# | `obscured` | the point was deliberately moved, by up to ~20 km |
# | `unknown` | iNaturalist reported no accuracy at all — not a promise of precision |
#
# Obscuring beats accuracy in that rule: an obscured record can still carry a small
# accuracy number, but that number describes the observer's GPS, not the point that
# was published.
#
# **If you are modelling terrain preference, filter to `precise` first.** If you
# are counting where and when people find things, keep everything — obscured
# records still answer that honestly at a regional scale.

# %%
# What share of the enrichment can be taken at face value?
if 'location_precision' not in df.columns:
    print("No location_precision column — re-run the iNaturalist fetch to collect it.\n"
          "(SKIP_INAT_FETCH must be unset, and the cached observations predate this field.)")
else:
    counts = df['location_precision'].value_counts(dropna=False)
    total = int(counts.sum())
    print("Location precision")
    for key in ['precise', 'coarse', 'obscured', 'unknown']:
        n = int(counts.get(key, 0))
        print(f"  {key:9s} {n:7,d}  {n / total * 100:5.1f}%")

    trustworthy = df[df['location_precision'] == 'precise']
    untrustworthy = total - len(trustworthy)
    print(f"\n{untrustworthy:,} of {total:,} rows ({untrustworthy / total * 100:.1f}%) carry terrain "
          f"sampled at a point iNaturalist moved or could not pin down.")

    # The same statistic computed both ways, to show whether it actually moves.
    # If these differ much, any terrain conclusion drawn from the full set is
    # partly an artefact of the obscured coordinates.
    for col in ['elevation', 'slope', 'ndvi', 'soil_moisture']:
        if col not in df.columns:
            continue
        all_rows = pd.to_numeric(df[col], errors='coerce').dropna()
        precise_rows = pd.to_numeric(trustworthy[col], errors='coerce').dropna()
        if len(precise_rows) < 30 or len(all_rows) < 30:
            continue
        print(f"  {col:15s} mean {all_rows.mean():9.3f} (all)  vs "
              f"{precise_rows.mean():9.3f} (precise only)   "
              f"sd {all_rows.std():8.3f} vs {precise_rows.std():8.3f}")

    # Working set for anything that reads the ground under an observation.
    precise_df = trustworthy
    print(f"\n`precise_df` holds the {len(precise_df):,} rows safe for terrain analysis.")

# %%
# Output files produced by the run
from pathlib import Path

for pattern in ('data/species/*.csv', 'data/enriched/*.csv',
                'public/data/*.geojson', 'public/data/*.json'):
    matches = sorted(Path(REPO_DIR).glob(pattern))
    total_mb = sum(m.stat().st_size for m in matches) / (1024 * 1024)
    print(f"{pattern:28s} {len(matches):4d} file(s)  {total_mb:7.2f} MB")

# %% [markdown]
# ## Step 7: Download Results (Optional)

# %%
# Zip the results for download
import shutil
from datetime import datetime

timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
archive_path = shutil.make_archive(
    os.path.join(WORKING_DIR, f'mushroom_data_{timestamp}'),
    'zip', REPO_DIR, base_dir='data',
)
print(f"\u2713 Created archive: {archive_path}")
print(f"  Size: {os.path.getsize(archive_path) / (1024*1024):.1f} MB")
print("\nDownload it from the notebook's Output tab.")

# %% [markdown]
# ## Notes & Troubleshooting
#
# ### Where does `EARTHENGINE_PROJECT` come from?
#
# It is the **project ID** of a Google Cloud project registered for Earth Engine —
# not the display name and not the project number.
#
# 1. https://console.cloud.google.com/ — the project picker lists every project
#    with its ID column. Create one if you have none.
# 2. https://code.earthengine.google.com/ — the Code Editor shows the active
#    project top-right, and in the Assets tab.
# 3. Not registered yet? https://code.earthengine.google.com/register attaches a
#    Cloud project to Earth Engine (free for noncommercial use).
# 4. Using gcloud already? `gcloud config get-value project`.
#
# `preflight.print_earthengine_project()` (Step 2) prints the one this run will use.
#
# ### Common Issues
#
# 1. **Earth Engine authentication**: if `ee.Initialize` fails, re-run Step 3 —
#    `ee.Authenticate(auth_mode='notebook')` works without a browser. Without a
#    working session the pipeline falls back to bulk raster downloads, which need
#    `OPENTOPOGRAPHY_API_KEY` plus CDS credentials and take dramatically longer.
#
# 2. **Earth Engine quotas**: sampling is batched by observation date — one request
#    per date, not per observation — but a very wide date range can still hit the
#    concurrent-request limit. Lower the parallelism:
#    ```python
#    import ee_enrich, species_store as store
#    df = store.load_all(store.SPECIES_DIR)
#    ee_enrich.enrich_precip_ee(df, max_workers=4)
#    ```
#
# 3. **Memory limits**: Kaggle notebooks have ~16GB RAM. Reduce the species list,
#    or set `SKIP_INAT_FETCH=1` to reuse what is already fetched.
#
# 4. **Session timeouts**: Kaggle sessions stop after ~12 hours. Every stage is
#    resumable — re-run Step 4 and it continues where it left off.
#
# ### Resuming an interrupted run
#
# Every enrichment stage only samples rows whose column is still empty, so re-running
# Step 4 continues rather than starting over. The `.done` marker in `data/enriched/`
# marks a finished run; `REFRESH_ALL=1` overrides it.
#
# ### Using the raster fallback deliberately
#
# ```python
# os.environ['USE_EARTH_ENGINE'] = '0'
# os.environ['FETCH_RASTERS'] = '1'
# run_pipeline.run_all(root=WORKING_DIR)
# ```
#
# ### Next Steps
#
# 1. Upload `public/data/observations.geojson` to the Nuxt frontend's `public/data/`
# 2. Deploy to Netlify or serve statically
# 3. Or continue analysis here with the enriched CSVs
#
# ### Why is `location_precision` missing or all `unknown`?
#
# The field comes from the iNaturalist fetch, so cached observations collected
# before it was added will not have it. Re-run with `SKIP_INAT_FETCH` unset to
# backfill. `unknown` means iNaturalist itself reported no positional accuracy for
# that record, which is common and is not the same as a precise location.
